# %%
from requests import get
from bs4 import BeautifulSoup as parseHTML
from pymongo import MongoClient

# %%
client = MongoClient('mongodb+srv://admin:mongo123@cluster0.o8xcc.mongodb.net/my_test?retryWrites=true&w=majority')
# client = MongoClient('mongodb+srv://mongo:mongo@cluster0.0lv9j.mongodb.net/myFirstDatabase?retryWrites=true&w=majority')
# test_db = client['test_db']
test_db = client['my_test'] # What is this used for?
ebay_collection = test_db['ebay']

# %%
url = 'https://www.ebay.com/sch/i.html?_from=R40&_trksid=p2380057.m570.l1311&_nkw=breitling+watches+for+men&_sacat=0'

# %%
ebayHTML = get(url).text
ebaySoup = parseHTML(ebayHTML, 'html.parser')

# %%
#ebaySoup
print(ebaySoup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 9]><html class="ie9 srp-ds6" lang="en"><![endif]-->
# <!--[if gt IE 9]><!-->
# <html class="srp-ds6" lang="en">
#  <!--<![endif]-->
#  <!--M#s0-1-->
#  <noscript class="x-page-config" id="s0-1">
#  </noscript>
#  <!--M/-->
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <script>
# ...

# %%
# Listing returned as an iterable list
listings = ebaySoup.find_all('li', class_='s-item s-item--watch-at-corner')

# %%
print(listings)

# %%
# Loop through returned listing
for listing in listings:
    try:
        link = listing.a['href']
        price = float(listing.find('span', class_='s-item__price').text.replace('$', '').replace(',', '')) #Transformation for ETL:  Remove $ and , and turn to integer 
        description = listing.find('h3', class_='s-item__title').text
        record = {
            'Link': link,
            'Price': price,
            'Description': description
        }
        print('inserting', link, price, description)
        ebay_collection.insert_one(record)
    except Exception as e:
        print('something broke...', e)
# Out:
# inserting https://www.ebay.com/itm/144108099698?hash=item218d831872:g:H9cAAOSwyoxg6Qeq 2425.0 New ListingBreitling Superocean II A17392 44mm (CASE SIDE STICKERS STILL ATTACHED!! )
# inserting https://www.ebay.com/itm/255044088981?epid=11045678880&hash=item3b61cff495:g:JfAAAOSwuclg5Ma5 650.0 breitling aerospace evo titanium
# inserting https://www.ebay.com/itm/164952878676?epid=17045686093&hash=item2667f52e54:g:1zwAAOSwLDNggmKd 1450.0 New ListingBreitling Superocean Blue Men's Watch - A17392
# inserting https://www.ebay.com/itm/274861043618?epid=9045959627&hash=item3ffefeafa2:g:5T4AAOSw0xhg5jk1 1725.0 BREITLING  CHRONOMAT EVOLUTION 44MM MEN'S GOLD/SS B13356 MODEL
# inserting https://www.ebay.com/itm/373645048902?hash=item56fefafc46:g:geEAAOSw4Qlg4Gzq 1750.0 New Listingbreitling chronomat b13352
# inserting https://www.ebay.com/itm/144108099698?hash=item218d831872:g:H9cAAOSwyoxg6Qeq 2425.0 New ListingBreitling Superocean II A17392 44mm (CASE SIDE STICKERS STILL ATTACHED!! )
# ...

# %%
ebay_collection

# %%
print(len(listings))
# Out:
# 57
